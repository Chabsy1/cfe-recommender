# %%
import sys
import os
import django
from pathlib import Path

# Manually set the root directory and the settings module
root_dir = "C:/Users/USER/Documents/recommender/src"
settings_module = "cfehome.settings"

os.environ.setdefault("DJANGO_SETTINGS_MODULE", settings_module)
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Add the root directory to sys.path
if root_dir not in sys.path:
    sys.path.insert(0, root_dir)
    print(f"'{root_dir}' successfully added to sys.path")

# Setup Django
try:
    django.setup()
    print("Django setup successfully")
except Exception as e:
    print(f"Error setting up Django: {e}")

# Now, access the settings and perform your operations
from django.conf import settings
import pandas as pd

# Ensure that the DATA_DIR setting is available
try:
    ratings_path = settings.DATA_DIR / "ratings_small.csv"
    if ratings_path.exists():
        print(f"Found ratings file at: {ratings_path}")
    else:
        print(f"Ratings file not found at: {ratings_path}")
except AttributeError as e:
    print(f"Error accessing DATA_DIR: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# 'C:/Users/USER/Documents/recommender/src' successfully added to sys.path
# Django setup successfully
# Found ratings file at: C:\Users\USER\Documents\recommender\src\data\ratings_small.csv

# %%
import pandas as pd
from django.conf import settings
from movies.models import Movie
from ratings.models import Rating


LINKS_SMALL_CSV = settings.DATA_DIR / 'links_small.csv'
LINKS_SMALL_CSV.exists()
# Out:
# True

# %%
qs = Rating.objects.all()
missing_movie_ids = []
for instance in qs:
    if instance.content_object is None:
        missing_movie_ids.append(instance.object_id)

_total = len(missing_movie_ids)
total_missing = list(set(missing_movie_ids))
print(len(total_missing), total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 _total = len(missing_movie_ids)
#       8 total_missing = list(set(missing_movie_ids))
# ----> 9 print(len(total_missing), total)
#
# NameError: name 'total' is not defined

# %%
print(len(total_missing), _total, qs.count())
# Out:
# 6392 57175 100004

# %%
links_df = pd.read_csv(LINKS_SMALL_CSV)
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ms_df = links_df.copy()[links_df.movieId.isin(total_missing)]
ms_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 3        4  114885  31357.0
# 6        7  114319  11860.0
# 7        8  112302  45325.0
# 8        9  114576   9091.0

# %%
ms_df.shape[0] == len(total_missing)
# Out:
# True

# %%
def enrich_imdb_col(val):
    val = str(val)
    if len(val) == 7:
       val = f"tt{val}"
       return val
    if len(val) == 6:
        val = f"tt0{val}"
        return val
    if len(val) == 5:
        val = f"tt00{val}"
        return val
    return val

# %%
ms_df['tt'] = ms_df['imdbId'].apply(enrich_imdb_col)
#ms_df.to_csv('')
ms_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt
# 0        1  114709    862.0  tt0114709
# 3        4  114885  31357.0  tt0114885
# 6        7  114319  11860.0  tt0114319
# 7        8  112302  45325.0  tt0112302
# 8        9  114576   9091.0  tt0114576

# %%
MOVIES_CSV = settings.DATA_DIR / 'movies_metadata.csv'
MOVIES_CSV.exists()
# Out:
# True

# %%
movies_cols = ['title', 'overview', 'release_date', 'imdb_id']
movies_df = pd.read_csv(MOVIES_CSV, usecols=movies_cols)
movies_df.head()
# Out:
#      imdb_id                                           overview release_date  \
# 0  tt0114709  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  tt0113497  When siblings Judy and Peter discover an encha...   1995-12-15
# 2  tt0113228  A family wedding reignites the ancient feud be...   1995-12-22
# 3  tt0114885  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4  tt0113041  Just when George Banks has recovered from his ...   1995-02-10
#
#                          title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
missing_movies_df = ms_df.merge(movies_df, left_on='tt', right_on='imdb_id')
missing_movies_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt    imdb_id  \
# 0        1  114709    862.0  tt0114709  tt0114709
# 1        4  114885  31357.0  tt0114885  tt0114885
# 2        7  114319  11860.0  tt0114319  tt0114319
# 3        8  112302  45325.0  tt0112302  tt0112302
# 4        9  114576   9091.0  tt0114576  tt0114576
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 2  An ugly duckling having undergone a remarkable...   1995-12-15
# 3  A mischievous young boy, Tom Sawyer, witnesses...   1995-12-22
# 4  International action superstar Jean Claude Van...   1995-12-22
#
#                title
# 0          Toy Story
# 1  Waiting to Exhale
# 2            Sabrina
# 3       Tom and Huck
# 4       Sudden Death

# %%
missing_movies_df['id'] = missing_movies_df['movieId']
missing_movies_df['id_alt'] = missing_movies_df['tmdbId'].apply(lambda x: str(int(x)))
missing_movies_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt    imdb_id  \
# 0        1  114709    862.0  tt0114709  tt0114709
# 1        4  114885  31357.0  tt0114885  tt0114885
# 2        7  114319  11860.0  tt0114319  tt0114319
# 3        8  112302  45325.0  tt0112302  tt0112302
# 4        9  114576   9091.0  tt0114576  tt0114576
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 2  An ugly duckling having undergone a remarkable...   1995-12-15
# 3  A mischievous young boy, Tom Sawyer, witnesses...   1995-12-22
# 4  International action superstar Jean Claude Van...   1995-12-22
#
#                title  id id_alt
# 0          Toy Story   1    862
# 1  Waiting to Exhale   4  31357
# 2            Sabrina   7  11860
# 3       Tom and Huck   8  45325
# 4       Sudden Death   9   9091

# %%
final_df = missing_movies_df.copy()[['id', 'id_alt', 'title']]
final_df['id_alt'] = final_df['id_alt'].astype(str)
final_df.head()
# Out:
#    id id_alt              title
# 0   1    862          Toy Story
# 1   4  31357  Waiting to Exhale
# 2   7  11860            Sabrina
# 3   8  45325       Tom and Huck
# 4   9   9091       Sudden Death

# %%
alt_id_list = final_df['id_alt'].to_list()

# %%
#movies_qs = Movie.objects.filter(id_in=alt_id_list)
movies_qs.count()
# Out:
# 6034

# %%
from django.forms.models import model_to_dict

# %%
from django.db import transaction

# Define batch size
batch_size = 100

# Prepare lists for bulk operations
objects_to_create = []
objects_to_delete = []
existing_titles = set(Movie.objects.values_list('title', flat=True))

movies_qs = Movie.objects.filter(id__in=alt_id_list)
for obj in movies_qs:
    data = final_df.copy()[final_df['id_alt'] == str(obj.id)]
    if data.shape[0] == 1:
        og_model_data = model_to_dict(obj)
        update_data = data.to_dict('records')[0]
        if obj.title == update_data.get('title'):
            og_model_data['id'] = update_data['id']
            new_model_data = {**og_model_data}

            # Check if title is already in the database or in the create list
            if new_model_data['title'] in existing_titles:
                print(f"Skipping duplicate title: {new_model_data['title']}")
                continue

            # Add title to existing_titles set
            existing_titles.add(new_model_data['title'])

            # Add to lists for bulk operations
            objects_to_create.append(Movie(**new_model_data))
            objects_to_delete.append(obj)

            # Perform batch operations
            if len(objects_to_create) >= batch_size:
                with transaction.atomic():
                    Movie.objects.bulk_create(objects_to_create)
                    for obj in objects_to_delete:
                        obj.delete()
                objects_to_create = []
                objects_to_delete = []

# Perform remaining operations outside the loop
if objects_to_create:
    with transaction.atomic():
        Movie.objects.bulk_create(objects_to_create)
        for obj in objects_to_delete:
            obj.delete()
# Out:
# Skipping duplicate title: American Beauty
# Skipping duplicate title: Citizen Kane
# Skipping duplicate title: Dancer in the Dark
# Skipping duplicate title: The Fifth Element
# Skipping duplicate title: My Life Without Me
# Skipping duplicate title: The Endless Summer
# Skipping duplicate title: Pirates of the Caribbean: The Curse of the Black Pearl
# Skipping duplicate title: Kill Bill: Vol. 1
# Skipping duplicate title: Jarhead
# Skipping duplicate title: Walk on Water
# Skipping duplicate title: Apocalypse Now
# Skipping duplicate title: Eternal Sunshine of the Spotless Mind
# Skipping duplicate title: A History of Violence
# Skipping duplicate title: Twelve Monkeys
# Skipping duplicate title: Talk to Her
# Skipping duplicate title: 8 Mile
# Skipping duplicate title: Absolute Power
# Skipping duplicate title: Paradise Now
# Skipping duplicate title: Brazil
# Skipping duplicate title: Billy Elliot
# Skipping duplicate title: American History X
# Skipping duplicate title: War of the Worlds
# Skipping duplicate title: Before Sunset
# Skipping duplicate title: Nausicaä of the Valley of the Wind
# Skipping duplicate title: Miami Vice
# Skipping duplicate title: Open Water
# Skipping duplicate title: Raiders of the Lost Ark
# Skipping duplicate title: Indiana Jones and the Last Crusade
# Skipping duplicate title: Beverly Hills Cop
# Skipping duplicate title: Anatomy of a Murder
# Skipping duplicate title: Beverly Hills Cop II
# Skipping duplicate title: Gladiator
# Skipping duplicate title: Lock, Stock and Two Smoking Barrels
# Skipping duplicate title: Back to the Future
# Skipping duplicate title: Scarface
# Skipping duplicate title: The Big Lebowski
# Skipping duplicate title: Match Point
# Skipping duplicate title: The Untouchables
# Skipping duplicate title: The Lord of the Rings: The Two Towers
# Skipping duplicate title: The Lord of the Rings: The Return of the King
# Skipping duplicate title: Princess Mononoke
# Skipping duplicate title: The Rolling Stones: Gimme Shelter
# Skipping duplicate title: O Brother, Where Art Thou?
# Skipping duplicate title: Dont Look Back
# Skipping duplicate title: Freaks
# Skipping duplicate title: Mifune
# Skipping duplicate title: Donnie Darko
# Skipping duplicate title: Wings of Desire
# Skipping duplicate title: Breaking the Waves
# Skipping duplicate title: Crouching Tiger, Hidden Dragon
# Skipping duplicate title: The Secret Life of Words
# Skipping duplicate title: Akira
# Skipping duplicate title: 48 Hrs.
# Skipping duplicate title: Lost in Translation
# Skipping duplicate title: Wilbur Wants to Kill Himself
# Skipping duplicate title: Knockin' on Heaven's Door
# Skipping duplicate title: K-PAX
# Skipping duplicate title: Predator 2
# Skipping duplicate title: 28 Days Later
# Skipping duplicate title: 20,000 Leagues Under the Sea
# Skipping duplicate title: The Big Blue
# Skipping duplicate title: Saw
# Skipping duplicate title: The Fisher King
# Skipping duplicate title: The Interpreter
# Skipping duplicate title: Minority Report
# Skipping duplicate title: The Good German
# Skipping duplicate title: A Clockwork Orange
# Skipping duplicate title: Lucky Number Slevin
# Skipping duplicate title: Sin City
# Skipping duplicate title: Sin City: A Dame to Kill For
# Skipping duplicate title: The Name of the Rose
# Skipping duplicate title: Trouble in Paradise
# Skipping duplicate title: Star Trek: First Contact
# Skipping duplicate title: Star Trek: Insurrection
# Skipping duplicate title: Star Trek: Nemesis
# Skipping duplicate title: Mean Streets
# Skipping duplicate title: The Wages of Fear
# Skipping duplicate title: Hotel Rwanda
# Skipping duplicate title: North by Northwest
# Skipping duplicate title: Saw III
# Skipping duplicate title: Ali: Fear Eats the Soul
# Skipping duplicate title: Indiana Jones and the Kingdom of the Crystal Skull
# Skipping duplicate title: The Terminator
# Skipping duplicate title: Berlin: Symphony of a Great City
# Skipping duplicate title: Boys Don't Cry
# Skipping duplicate title: Bride of Frankenstein
# Skipping duplicate title: Syriana
# Skipping duplicate title: Rumble Fish
# Skipping duplicate title: The Wanderers
# Skipping duplicate title: The Cabinet of Dr. Caligari
# Skipping duplicate title: The Godfather: Part II
# Skipping duplicate title: High Fidelity
# Skipping duplicate title: King Kong
# Skipping duplicate title: About a Boy
# Skipping duplicate title: Zatoichi
# Skipping duplicate title: The Killing
# Skipping duplicate title: Pocketful of Miracles
# Skipping duplicate title: The War of the Roses
# Skipping duplicate title: In China They Eat Dogs
# Skipping duplicate title: Live and Let Die
# Skipping duplicate title: Stolen Kisses
# Skipping duplicate title: Bed and Board
# Skipping duplicate title: Love on the Run
# Skipping duplicate title: Cat on a Hot Tin Roof
# Skipping duplicate title: The King of Comedy
# Skipping duplicate title: Batman Begins
# Skipping duplicate title: The White Sound
# Skipping duplicate title: The Edukators
# Skipping duplicate title: Amadeus
# Skipping duplicate title: Terminator 2: Judgment Day
# Skipping duplicate title: Pirates of the Caribbean: At World's End
# Skipping duplicate title: Bull Durham
# Skipping duplicate title: Casablanca
# Skipping duplicate title: Riding Giants
# Skipping duplicate title: A River Runs Through It
# Skipping duplicate title: Desert Hearts
# Skipping duplicate title: Meet Joe Black
# Skipping duplicate title: Ocean's Thirteen
# Skipping duplicate title: The Science of Sleep
# Skipping duplicate title: Rio Bravo
# Skipping duplicate title: Notorious
# Skipping duplicate title: Beverly Hills Cop III
# Skipping duplicate title: Rome, Open City
# Skipping duplicate title: Broken Flowers
# Skipping duplicate title: Once Upon a Time in America
# Skipping duplicate title: Catwoman
# Skipping duplicate title: True Romance
# Skipping duplicate title: Mambo Italiano
# Skipping duplicate title: Mystic River
# Skipping duplicate title: Snakes on a Plane
# Skipping duplicate title: Brother
# Skipping duplicate title: Inspector Gadget
# Skipping duplicate title: Once Upon a Time in the West
# Skipping duplicate title: Duck, You Sucker
# Skipping duplicate title: Good bye, Lenin!
# Skipping duplicate title: Everything is Illuminated
# Skipping duplicate title: Harold and Maude
# Skipping duplicate title: Eyes Wide Shut
# Skipping duplicate title: Alien
# Skipping duplicate title: The Devil Wears Prada
# Skipping duplicate title: Head-On
# Skipping duplicate title: A Nightmare on Elm Street
# Skipping duplicate title: To Catch a Thief
# Skipping duplicate title: Mala Noche
# Skipping duplicate title: Das Boot
# Skipping duplicate title: Inside Man
# Skipping duplicate title: 12 Angry Men
# Skipping duplicate title: A Fistful of Dollars
# Skipping duplicate title: Chocolat
# Skipping duplicate title: Kill Bill: Vol. 2
# Skipping duplicate title: Capote
# Skipping duplicate title: Garden State
# Skipping duplicate title: Driving Miss Daisy
# Skipping duplicate title: The Straight Story
# Skipping duplicate title: The English Patient
# Skipping duplicate title: Ice Age
# Skipping duplicate title: Mon oncle
# Skipping duplicate title: The Good, the Bad and the Ugly
# Skipping duplicate title: One, Two, Three
# Skipping duplicate title: Mary Poppins
# Skipping duplicate title: The Day After Tomorrow
# Skipping duplicate title: Cube²: Hypercube
# Skipping duplicate title: La Dolce Vita
# Skipping duplicate title: Aliens vs Predator: Requiem
# Skipping duplicate title: Human Nature
# Skipping duplicate title: Caché
# Skipping duplicate title: The Idiots
# Skipping duplicate title: Bend It Like Beckham
# Skipping duplicate title: Erin Brockovich
# Skipping duplicate title: Stranger Than Paradise
# Skipping duplicate title: 21 Grams
# Skipping duplicate title: Bonnie and Clyde
# Skipping duplicate title: Drugstore Cowboy
# Skipping duplicate title: Monsoon Wedding
# Skipping duplicate title: Shaft
# Skipping duplicate title: Wild at Heart
# Skipping duplicate title: The African Queen
# Skipping duplicate title: Good Will Hunting
# Skipping duplicate title: The Seventh Seal
# Skipping duplicate title: Being John Malkovich
# Skipping duplicate title: The Green Mile
# Skipping duplicate title: Grizzly Man
# Skipping duplicate title: Fail-Safe
# Skipping duplicate title: Poseidon
# Skipping duplicate title: Monster
# Skipping duplicate title: Marnie
# Skipping duplicate title: Love Actually
# Skipping duplicate title: One Flew Over the Cuckoo's Nest
# Skipping duplicate title: Dial M for Murder
# Skipping duplicate title: The Blues Brothers
# Skipping duplicate title: Ladyhawke
# Skipping duplicate title: A Grand Day Out
# Skipping duplicate title: The Wrong Trousers
# Skipping duplicate title: The Curse of the Were-Rabbit
# Skipping duplicate title: Terminator Salvation
# Skipping duplicate title: Flashdance
# Skipping duplicate title: Psycho
# Skipping duplicate title: The Man with the Golden Arm
# Skipping duplicate title: The Crime of Padre Amaro
# Skipping duplicate title: Blackmail
# Skipping duplicate title: Transamerica
# Skipping duplicate title: Rashomon
# Skipping duplicate title: Dogville
# Skipping duplicate title: Spider-Man
# Skipping duplicate title: Spider-Man 2
# Skipping duplicate title: Spider-Man 3
# Skipping duplicate title: Constantine
# Skipping duplicate title: Die Hard
# Skipping duplicate title: Rear Window
# Skipping duplicate title: The Birds
# Skipping duplicate title: Frenzy
# Skipping duplicate title: The Man Who Knew Too Much
# Skipping duplicate title: To Die For
# Skipping duplicate title: Jaws 2
# Skipping duplicate title: Jaws: The Revenge
# Skipping duplicate title: Life of Brian
# Skipping duplicate title: 2 Fast 2 Furious
# Skipping duplicate title: Wag the Dog
# Skipping duplicate title: Big Fish
# Skipping duplicate title: Silent Hill
# Skipping duplicate title: The Hours
# Skipping duplicate title: The Da Vinci Code
# Skipping duplicate title: The Conversation
# Skipping duplicate title: Solaris
# Skipping duplicate title: The Terminal
# Skipping duplicate title: To Kill a Mockingbird
# Skipping duplicate title: The Grapes of Wrath
# Skipping duplicate title: Full Metal Jacket
# Skipping duplicate title: E.T. the Extra-Terrestrial
# Skipping duplicate title: The Matrix
# Skipping duplicate title: The Matrix Reloaded
# Skipping duplicate title: Men in Black II
# Skipping duplicate title: Munich
# Skipping duplicate title: The Passion of the Christ
# Skipping duplicate title: The Last Samurai
# Skipping duplicate title: Wild Things
# Skipping duplicate title: The Bodyguard
# Skipping duplicate title: Ghostbusters
# Skipping duplicate title: The Ninth Gate
# Skipping duplicate title: A Fish Called Wanda
# Skipping duplicate title: The Killing Fields
# Skipping duplicate title: The Usual Suspects
# Skipping duplicate title: Sunrise: A Song of Two Humans
# Skipping duplicate title: Stalag 17
# Skipping duplicate title: Soldier of Orange
# Skipping duplicate title: Bridget Jones's Diary
# Skipping duplicate title: Angel Heart
# Skipping duplicate title: THX 1138
# Skipping duplicate title: Life Is Beautiful
# Skipping duplicate title: Lost Highway
# Skipping duplicate title: When Harry Met Sally...
# Skipping duplicate title: Catch Me If You Can
# Skipping duplicate title: Requiem for a Dream
# Skipping duplicate title: Butch Cassidy and the Sundance Kid
# Skipping duplicate title: Battleship Potemkin
# Skipping duplicate title: A.I. Artificial Intelligence
# Skipping duplicate title: Dr. No
# Skipping duplicate title: Final Fantasy VII: Advent Children
# Skipping duplicate title: Boyz n the Hood
# Skipping duplicate title: Troy
# Skipping duplicate title: Nosferatu
# Skipping duplicate title: Paris, Texas
# Skipping duplicate title: From Russia with Love
# Skipping duplicate title: Goldfinger
# Skipping duplicate title: The Tin Drum
# Skipping duplicate title: La Jetée
# Skipping duplicate title: Saw IV
# Skipping duplicate title: Twister
# Skipping duplicate title: Ben-Hur
# Skipping duplicate title: You Only Live Twice
# Skipping duplicate title: On Her Majesty's Secret Service
# Skipping duplicate title: Nanook of the North
# Skipping duplicate title: Oldboy
# Skipping duplicate title: Harry Potter and the Order of the Phoenix
# Skipping duplicate title: Pearl Harbor
# Skipping duplicate title: Out of the Past
# Skipping duplicate title: Aliens
# Skipping duplicate title: Diamonds Are Forever
# Skipping duplicate title: The Man with the Golden Gun
# Skipping duplicate title: Dead Man Walking
# Skipping duplicate title: Pickpocket
# Skipping duplicate title: Pink Flamingos
# Skipping duplicate title: Meet the Fockers
# Skipping duplicate title: The Shining
# Skipping duplicate title: For Your Eyes Only
# Skipping duplicate title: Octopussy
# Skipping duplicate title: Our Hospitality
# Skipping duplicate title: A Streetcar Named Desire
# Skipping duplicate title: Annie Hall
# Skipping duplicate title: A Hard Day's Night
# Skipping duplicate title: A View to a Kill
# Skipping duplicate title: The Living Daylights
# Skipping duplicate title: GoldenEye
# Skipping duplicate title: Finding Forrester
# Skipping duplicate title: Four Weddings and a Funeral
# Skipping duplicate title: Together
# Skipping duplicate title: Top Gun
# Skipping duplicate title: The Last Emperor
# Skipping duplicate title: Gentlemen Prefer Blondes
# Skipping duplicate title: Monty Python and the Holy Grail
# Skipping duplicate title: Braindead
# Skipping duplicate title: Evil Dead II
# Skipping duplicate title: Army of Darkness
# Skipping duplicate title: Harry Potter and the Half-Blood Prince
# Skipping duplicate title: From Hell
# Skipping duplicate title: Home Alone 2: Lost in New York
# Skipping duplicate title: The Rules of the Game
# Skipping duplicate title: Monsieur  Hulot's Holiday
# Skipping duplicate title: The Passion of Joan of Arc
# Skipping duplicate title: Gandhi
# Skipping duplicate title: Kolya
# Skipping duplicate title: Almost Famous
# Skipping duplicate title: The Fog
# Skipping duplicate title: Blue Velvet
# Skipping duplicate title: The Omen
# Skipping duplicate title: Cruel Intentions
# Skipping duplicate title: Persona
# Skipping duplicate title: Good Morning, Vietnam
# Skipping duplicate title: Night and Fog
# Skipping duplicate title: Se7en
# Skipping duplicate title: Shrek
# Skipping duplicate title: Shrek 2
# Skipping duplicate title: Silent Running
# Skipping duplicate title: An American Werewolf in London
# Skipping duplicate title: Austin Powers: International Man of Mystery
# Skipping duplicate title: Austin Powers: The Spy Who Shagged Me
# Skipping duplicate title: Sleepers
# Skipping duplicate title: JFK
# Skipping duplicate title: Judgment at Nuremberg
# Skipping duplicate title: Jin-Roh: The Wolf Brigade
# Skipping duplicate title: Moulin Rouge!
# Skipping duplicate title: Playing by Heart
# Skipping duplicate title: Forbidden Planet
# Skipping duplicate title: Umberto D.
# Skipping duplicate title: Videodrome
# Skipping duplicate title: American Graffiti
# Skipping duplicate title: Close Encounters of the Third Kind
# Skipping duplicate title: In the Mood for Love
# Skipping duplicate title: 2046
# Skipping duplicate title: Dragonslayer
# Skipping duplicate title: Krull
# Skipping duplicate title: A Christmas Story
# Skipping duplicate title: Enemy at the Gates
# Skipping duplicate title: The Mask
# Skipping duplicate title: Black Hawk Down
# Skipping duplicate title: Who Framed Roger Rabbit
# Skipping duplicate title: WarGames
# Skipping duplicate title: Total Recall
# Skipping duplicate title: Toy Story
# Skipping duplicate title: Cool Runnings
# Skipping duplicate title: Tsotsi
# Skipping duplicate title: Planet of the Apes
# Skipping duplicate title: The Color Purple
# Skipping duplicate title: Frank Herbert's Dune
# Skipping duplicate title: Coffee and Cigarettes
# Skipping duplicate title: The Flintstones
# Skipping duplicate title: The Flintstones in Viva Rock Vegas
# Skipping duplicate title: All the President's Men
# Skipping duplicate title: Delicatessen
# Skipping duplicate title: Andrei Rublev
# Skipping duplicate title: Aparajito
# Skipping duplicate title: Birdman of Alcatraz
# Skipping duplicate title: City Lights
# Skipping duplicate title: The City of Lost Children
# Skipping duplicate title: Cool Hand Luke
# Skipping duplicate title: The Bank Dick
# Skipping duplicate title: The Thomas Crown Affair
# Skipping duplicate title: Bullitt
# Skipping duplicate title: Blind Date
# Skipping duplicate title: Cars
# Skipping duplicate title: Dawn of the Dead
# Skipping duplicate title: Do the Right Thing
# Skipping duplicate title: Don't Look Now
# Skipping duplicate title: Rififi
# Skipping duplicate title: The Pink Panther
# Skipping duplicate title: The Lady Vanishes
# Skipping duplicate title: Lawrence of Arabia
# Skipping duplicate title: Halloween
# Skipping duplicate title: Kindergarten Cop
# Skipping duplicate title: Madagascar
# Skipping duplicate title: Mission: Impossible
# Skipping duplicate title: Mission: Impossible II
# Skipping duplicate title: The Gold Rush
# Skipping duplicate title: Dog Day Afternoon
# Skipping duplicate title: Paths of Glory
# Skipping duplicate title: Sweet Smell of Success
# Skipping duplicate title: Tabu
# Skipping duplicate title: Irreversible
# Skipping duplicate title: The Man Who Would Be King
# Skipping duplicate title: Dirty Harry
# Skipping duplicate title: Eraserhead
# Skipping duplicate title: The China Syndrome
# Skipping duplicate title: The Hustler
# Skipping duplicate title: The Man Who Fell to Earth
# Skipping duplicate title: Sleuth
# Skipping duplicate title: Straw Dogs
# Skipping duplicate title: Stagecoach
# Skipping duplicate title: Double Indemnity
# Skipping duplicate title: Mulholland Drive
# Skipping duplicate title: The Leopard
# Skipping duplicate title: Sommersby
# Skipping duplicate title: Shower
# Skipping duplicate title: The French Connection
# Skipping duplicate title: Blow-Up
# Skipping duplicate title: Breathless
# Skipping duplicate title: The Hidden Fortress
# Skipping duplicate title: Arlington Road
# Skipping duplicate title: Black Cat, White Cat
# Skipping duplicate title: Whale Rider
# Skipping duplicate title: Point Break
# Skipping duplicate title: The Thirteenth Floor
# Skipping duplicate title: The Third Man
# Skipping duplicate title: Escape from New York
# Skipping duplicate title: The Wind That Shakes the Barley
# Skipping duplicate title: Dreamgirls
# Skipping duplicate title: The Miracle Worker
# Skipping duplicate title: Babel
# Skipping duplicate title: The Queen
# Skipping duplicate title: The Remains of the Day
# Skipping duplicate title: Rocky Balboa
# Skipping duplicate title: The Good Shepherd
# Skipping duplicate title: Hannibal Rising
# Skipping duplicate title: Hollywoodland
# Skipping duplicate title: Ghost Rider
# Skipping duplicate title: Letters from Iwo Jima
# Skipping duplicate title: Breaking and Entering
# Skipping duplicate title: The Host
# Skipping duplicate title: Because I Said So
# Skipping duplicate title: Street Kings
# Skipping duplicate title: Meet the Robinsons
# Skipping duplicate title: Mr. Bean's Holiday
# Skipping duplicate title: 300
# Skipping duplicate title: The Dreamers
# Skipping duplicate title: 3-Iron
# Skipping duplicate title: Dogtown and Z-Boys
# Skipping duplicate title: A Brief History of Time
# Skipping duplicate title: American Psycho
# Skipping duplicate title: Frida
# Skipping duplicate title: The Hobbit
# Skipping duplicate title: Sex and Lucia
# Skipping duplicate title: Monster's Ball
# Skipping duplicate title: Rocky II
# Skipping duplicate title: First Blood
# Skipping duplicate title: Rambo: First Blood Part II
# Skipping duplicate title: Rambo III
# Skipping duplicate title: Rocky III
# Skipping duplicate title: Rocky IV
# Skipping duplicate title: Rocky V
# Skipping duplicate title: Sweet Sixteen
# Skipping duplicate title: Houseboat
# Skipping duplicate title: Shortbus
# Skipping duplicate title: Lights in the Dusk
# Skipping duplicate title: The Fountain
# Skipping duplicate title: Me and You and Everyone We Know
# Skipping duplicate title: Superstar: The Karen Carpenter Story
# Skipping duplicate title: Y Tu Mamá También
# Skipping duplicate title: Born into Brothels
# Skipping duplicate title: Nostalgia
# Skipping duplicate title: Mirror
# Skipping duplicate title: Stalker
# Skipping duplicate title: The Pursuit of Happyness
# Skipping duplicate title: Duel at Diablo
# Skipping duplicate title: Ae Fond Kiss...
# Skipping duplicate title: City Slickers
# Skipping duplicate title: La Vie en Rose
# Skipping duplicate title: Sex, Lies, and Videotape
# Skipping duplicate title: Lovers of the Arctic Circle
# Skipping duplicate title: Pan's Labyrinth
# Skipping duplicate title: The Departed
# Skipping duplicate title: Perfume: The Story of a Murderer
# Skipping duplicate title: Once Upon a Time in Mexico
# Skipping duplicate title: 25th Hour
# Skipping duplicate title: Bowling for Columbine
# Skipping duplicate title: The Devil's Backbone
# Skipping duplicate title: Anna and the King
# Skipping duplicate title: Little Children
# Skipping duplicate title: Superman Returns
# Skipping duplicate title: Hellboy
# Skipping duplicate title: Curse of the Golden Flower
# Skipping duplicate title: Kingdom of Heaven
# Skipping duplicate title: Cool as Ice
# Skipping duplicate title: Teenage Mutant Ninja Turtles II: The Secret of the Ooze
# Skipping duplicate title: Teenage Mutant Ninja Turtles
# Skipping duplicate title: Teenage Mutant Ninja Turtles III
# Skipping duplicate title: The Last King of Scotland
# Skipping duplicate title: Spy Game
# Skipping duplicate title: Changing Lanes
# Skipping duplicate title: Collateral
# Skipping duplicate title: Imagine Me & You
# Skipping duplicate title: The Lost Boys
# Skipping duplicate title: Pieces of April
# Skipping duplicate title: The Spanish Apartment
# Skipping duplicate title: 23
# Skipping duplicate title: Sunless
# Skipping duplicate title: I Stand Alone
# Skipping duplicate title: Live Free or Die Hard
# Skipping duplicate title: Resident Evil
# Skipping duplicate title: Resident Evil: Apocalypse
# Skipping duplicate title: Raging Bull
# Skipping duplicate title: Apocalypto
# Skipping duplicate title: The Holiday
# Skipping duplicate title: Lammbock
# Skipping duplicate title: School of Rock
# Skipping duplicate title: Bring It On
# Skipping duplicate title: Nowhere in Africa
# Skipping duplicate title: A Shot in the Dark
# Skipping duplicate title: Meet the Parents
# Skipping duplicate title: Cape Fear
# Skipping duplicate title: I Heart Huckabees
# Skipping duplicate title: The Double Life of Veronique
# Skipping duplicate title: Fever Pitch
# Skipping duplicate title: Still Crazy
# Skipping duplicate title: The Way of the Gun
# Skipping duplicate title: Trading Places
# Skipping duplicate title: Brubaker
# Skipping duplicate title: Liar Liar
# Skipping duplicate title: Vivre Sa Vie
# Skipping duplicate title: Jules and Jim
# Skipping duplicate title: The People vs. Larry Flynt
# Skipping duplicate title: Bedazzled
# Skipping duplicate title: Forces of Nature
# Skipping duplicate title: Freedom Writers
# Skipping duplicate title: The Recruit
# Skipping duplicate title: Bill & Ted's Excellent Adventure
# Skipping duplicate title: Bill & Ted's Bogus Journey
# Skipping duplicate title: The Dirty Dozen
# Skipping duplicate title: Gigantics
# Skipping duplicate title: State of Grace
# Skipping duplicate title: March of the Penguins
# Skipping duplicate title: The Professional
# Skipping duplicate title: Day for Night
# Skipping duplicate title: Ray
# Skipping duplicate title: King Kong vs. Godzilla
# Skipping duplicate title: Beneath the Planet of the Apes
# Skipping duplicate title: Escape from the Planet of the Apes
# Skipping duplicate title: Conquest of the Planet of the Apes
# Skipping duplicate title: Little Buddha
# Skipping duplicate title: Hostel
# Skipping duplicate title: Re-Animator
# Skipping duplicate title: The Devil's Rejects
# Skipping duplicate title: Anatomy
# Skipping duplicate title: Misery
# Skipping duplicate title: Battle for the Planet of the Apes
# Skipping duplicate title: Fahrenheit 451
# Skipping duplicate title: The Cider House Rules
# Skipping duplicate title: The Last Metro
# Skipping duplicate title: The Front
# Skipping duplicate title: The Incredible Hulk
# Skipping duplicate title: Iron Man
# Skipping duplicate title: Bird on a Wire
# Skipping duplicate title: The Forbidden Kingdom
# Skipping duplicate title: INLAND EMPIRE
# Skipping duplicate title: The Mummy Returns
# Skipping duplicate title: The Mummy: Tomb of the Dragon Emperor
# Skipping duplicate title: Next
# Skipping duplicate title: Captain America: The First Avenger
# Skipping duplicate title: City of Hope
# Skipping duplicate title: The Big One
# Skipping duplicate title: Jesus Camp
# Skipping duplicate title: Fahrenheit 9/11
# Skipping duplicate title: An Inconvenient Truth
# Skipping duplicate title: To End All Wars
# Skipping duplicate title: Au Revoir les Enfants
# Skipping duplicate title: Footloose
# Skipping duplicate title: The Piano Teacher
# Skipping duplicate title: Stuck on You
# Skipping duplicate title: Max Dugan Returns
# Skipping duplicate title: Elephant
# Skipping duplicate title: Velvet Goldmine
# Skipping duplicate title: The Rules of Attraction
# Skipping duplicate title: Nowhere
# Skipping duplicate title: A Chorus Line
# Skipping duplicate title: Phone Booth
# Skipping duplicate title: Shoot the Piano Player
# Skipping duplicate title: 50 First Dates
# Skipping duplicate title: Over the Top
# Skipping duplicate title: Russian Dolls
# Skipping duplicate title: The Story of Adele H
# Skipping duplicate title: The Next Best Thing
# Skipping duplicate title: Murder, My Sweet
# Skipping duplicate title: In My Skin
# Skipping duplicate title: Dig!
# Skipping duplicate title: The Long Goodbye
# Skipping duplicate title: Man on the Moon
# Skipping duplicate title: World Trade Center
# Skipping duplicate title: The Transformers: The Movie
# Skipping duplicate title: Transformers
# Skipping duplicate title: Pirates of the Caribbean: On Stranger Tides
# Skipping duplicate title: Guess Who's Coming to Dinner
# Skipping duplicate title: Red Dawn
# Skipping duplicate title: The Men
# Skipping duplicate title: Malcolm X
# Skipping duplicate title: The Karate Kid
# Skipping duplicate title: Marie Antoinette
# Skipping duplicate title: The Fortune Cookie
# Skipping duplicate title: The Empire Strikes Back
# Skipping duplicate title: Return of the Jedi
# Skipping duplicate title: Star Wars: Episode I - The Phantom Menace
# Skipping duplicate title: Star Wars: Episode II - Attack of the Clones
# Skipping duplicate title: Star Wars: Episode III - Revenge of the Sith
# Skipping duplicate title: In Good Company
# Skipping duplicate title: The Beach
# Skipping duplicate title: The 13th Warrior
# Skipping duplicate title: The Sea Inside
# Skipping duplicate title: Away from Her
# Skipping duplicate title: Sweet November
# Skipping duplicate title: Irina Palm
# Skipping duplicate title: Twin Peaks: Fire Walk with Me
# Skipping duplicate title: 11'09''01 - September 11
# Skipping duplicate title: Hulk
# Skipping duplicate title: The Amazing Spider-Man
# Skipping duplicate title: The Others
# Skipping duplicate title: Shakespeare in Love
# Skipping duplicate title: Exodus
# Skipping duplicate title: Bunny Lake Is Missing
# Skipping duplicate title: Nell
# Skipping duplicate title: eXistenZ
# Skipping duplicate title: An Unfinished Life
# Skipping duplicate title: Manderlay
# Skipping duplicate title: The Butterfly Effect
# Skipping duplicate title: Gerry
# Skipping duplicate title: Enough
# Skipping duplicate title: 8 Women
# Skipping duplicate title: My Name Is Bruce
# Skipping duplicate title: A Friend of Mine
# Skipping duplicate title: Alexander
# Skipping duplicate title: Fools Rush In
# Skipping duplicate title: The Grudge
# Skipping duplicate title: Jezebel
# Skipping duplicate title: Stage Fright
# Skipping duplicate title: Fantastic 4: Rise of the Silver Surfer
# Skipping duplicate title: 1984
# Skipping duplicate title: The Constant Gardener
# Skipping duplicate title: Paranoid Park
# Skipping duplicate title: Planet Terror
# Skipping duplicate title: Lara Croft: Tomb Raider
# Skipping duplicate title: Lara Croft Tomb Raider: The Cradle of Life
# Skipping duplicate title: Two Brothers
# Skipping duplicate title: In the Bedroom
# Skipping duplicate title: Aguirre: The Wrath of God
# Skipping duplicate title: We Own the Night
# Skipping duplicate title: Sister Act
# Skipping duplicate title: Bell, Book and Candle
# Skipping duplicate title: Lorenzo's Oil
# Skipping duplicate title: Persepolis
# Skipping duplicate title: The Diving Bell and the Butterfly
# Skipping duplicate title: The Edge of Heaven
# Skipping duplicate title: The Wedding Planner
# Skipping duplicate title: Mr. Deeds
# Skipping duplicate title: Hidalgo
# Skipping duplicate title: The Patriot
# Skipping duplicate title: Say Anything...
# Skipping duplicate title: Training Day
# Skipping duplicate title: Along Came a Spider
# Skipping duplicate title: The Lake House
# Skipping duplicate title: The Gift
# Skipping duplicate title: I, Robot
# Skipping duplicate title: Open Range
# Skipping duplicate title: The Station Agent
# Skipping duplicate title: Original Sin
# Skipping duplicate title: National Treasure
# Skipping duplicate title: Ratatouille
# Skipping duplicate title: Mission to Mars
# Skipping duplicate title: The Whole Nine Yards
# Skipping duplicate title: Flirting with Disaster
# Skipping duplicate title: Prizzi's Honor
# Skipping duplicate title: X-Men Origins: Wolverine
# Skipping duplicate title: Birthday Girl
# Skipping duplicate title: Romeo Must Die
# Skipping duplicate title: The Last Castle
# Skipping duplicate title: American Pie
# Skipping duplicate title: Rush Hour
# Skipping duplicate title: Wasabi
# Skipping duplicate title: Payback
# Skipping duplicate title: Final Fantasy: The Spirits Within
# Skipping duplicate title: Out of Time
# Skipping duplicate title: L.A. Confidential
# Skipping duplicate title: Days of Thunder
# Skipping duplicate title: The Whole Ten Yards
# Skipping duplicate title: Me, Myself & Irene
# Skipping duplicate title: The Perfect Storm
# Skipping duplicate title: The Time Machine
# Skipping duplicate title: Kiss of the Dragon
# Skipping duplicate title: The Cotton Club
# Skipping duplicate title: Body of Evidence
# Skipping duplicate title: Dixie Chicks: Shut Up and Sing
# Skipping duplicate title: Reindeer Games
# Skipping duplicate title: Voyage to the Bottom of the Sea
# Skipping duplicate title: Fantastic Voyage
# Skipping duplicate title: Chill Factor
# Skipping duplicate title: Breakdown
# Skipping duplicate title: Wet Hot American Summer
# Skipping duplicate title: The Glass House
# Skipping duplicate title: Big Trouble
# Skipping duplicate title: My Tutor
# Skipping duplicate title: Death at a Funeral
# Skipping duplicate title: Lassie Come Home
# Skipping duplicate title: Alice in the Cities
# Skipping duplicate title: Aimee & Jaguar
# Skipping duplicate title: Nightwatch
# Skipping duplicate title: Unfaithful
# Skipping duplicate title: Eastern Promises
# Skipping duplicate title: Capturing the Friedmans
# Skipping duplicate title: Veronika Voss
# Skipping duplicate title: Music Box
# Skipping duplicate title: Paris, je t'aime
# Skipping duplicate title: The Last Mimzy
# Skipping duplicate title: Day Watch
# Skipping duplicate title: Stardust
# Skipping duplicate title: The Seeker: The Dark Is Rising
# Skipping duplicate title: The General's Daughter
# Skipping duplicate title: Bicentennial Man
# Skipping duplicate title: Big
# Skipping duplicate title: Mr. Magorium's Wonder Emporium
# Skipping duplicate title: Cold Mountain
# Skipping duplicate title: Clerks II
# Skipping duplicate title: Kafka
# Skipping duplicate title: A Pyromaniac's Love Story
# Skipping duplicate title: Inkheart
# Skipping duplicate title: Married to the Mob
# Skipping duplicate title: Field of Dreams
# Skipping duplicate title: Taxi
# Skipping duplicate title: Taxi 2
# Skipping duplicate title: Reign Over Me
# Skipping duplicate title: 10 Items or Less
# Skipping duplicate title: Sicko
# Skipping duplicate title: Saving Grace
# Skipping duplicate title: The Bear
# Skipping duplicate title: The Greatest Story Ever Told
# Skipping duplicate title: The Chronicles of Narnia: Prince Caspian
# Skipping duplicate title: Children of Paradise
# Skipping duplicate title: Tie Me Up! Tie Me Down!
# Skipping duplicate title: Belle Époque
# Skipping duplicate title: Eragon
# Skipping duplicate title: Lady Snowblood
# Skipping duplicate title: The Princess Bride
# Skipping duplicate title: The Bourne Identity
# Skipping duplicate title: The Bourne Ultimatum
# Skipping duplicate title: Nobody Knows
# Skipping duplicate title: Spanglish
# Skipping duplicate title: Zazie dans le métro
# Skipping duplicate title: Joe Versus the Volcano
# Skipping duplicate title: Code 46
# Skipping duplicate title: Born on the Fourth of July
# Skipping duplicate title: Short Circuit
# Skipping duplicate title: Maid to Order
# Skipping duplicate title: Planes, Trains and Automobiles
# Skipping duplicate title: Prelude to a Kiss
# Skipping duplicate title: Innerspace
# Skipping duplicate title: Uncle Buck
# Skipping duplicate title: The Great Outdoors
# Skipping duplicate title: Armed and Dangerous
# Skipping duplicate title: An Officer and a Gentleman
# Skipping duplicate title: Mr. Jones
# Skipping duplicate title: Two Weeks Notice
# Skipping duplicate title: The Game
# Skipping duplicate title: What Lies Beneath
# Skipping duplicate title: House of 1000 Corpses
# Skipping duplicate title: Airplane II: The Sequel
# Skipping duplicate title: Dark City
# Skipping duplicate title: The Blair Witch Project
# Skipping duplicate title: Sleepy Hollow
# Skipping duplicate title: The Bounty
# Skipping duplicate title: Ringu
# Skipping duplicate title: Signs
# Skipping duplicate title: Evan Almighty
# Skipping duplicate title: Z
# Skipping duplicate title: Indochine
# Skipping duplicate title: Naked Lunch
# Skipping duplicate title: 15 Minutes
# Skipping duplicate title: 24 Hour Party People
# Skipping duplicate title: 40 Days and 40 Nights
# Skipping duplicate title: About Schmidt
# Skipping duplicate title: The Lodger: A Story of the London Fog
# Skipping duplicate title: Les Amants du Pont-Neuf
# Skipping duplicate title: American Gigolo
# Skipping duplicate title: American Pie 2
# Skipping duplicate title: American Splendor
# Skipping duplicate title: The Curse of the Jade Scorpion
# Skipping duplicate title: Pierrot le Fou
# Skipping duplicate title: Pitch Black
# Skipping duplicate title: Reality Bites
# Skipping duplicate title: Rumor Has It...
# Skipping duplicate title: Identity
# Skipping duplicate title: An Angel at My Table
# Skipping duplicate title: The Lady and the Duke
# Skipping duplicate title: Around the World in Eighty Days
# Skipping duplicate title: As Good as It Gets
# Skipping duplicate title: The Astronaut's Wife
# Skipping duplicate title: Michael
# Skipping duplicate title: License to Wed
# Skipping duplicate title: The Golem: How He Came Into the World
# Skipping duplicate title: Becoming Jane
# Skipping duplicate title: Ghostbusters II
# Skipping duplicate title: The Lost World
# Skipping duplicate title: Pacific Heights
# Skipping duplicate title: How to Steal a Million
# Skipping duplicate title: The Trial
# Skipping duplicate title: Dr. Jekyll and Mr. Hyde
# Skipping duplicate title: The Fearless Vampire Killers
# Skipping duplicate title: 42nd Street
# Skipping duplicate title: Duck Soup
# Skipping duplicate title: Abbott and Costello Meet Frankenstein
# Skipping duplicate title: The Ghost of Frankenstein
# Skipping duplicate title: Frankenstein Meets the Wolf Man
# Skipping duplicate title: Top Hat
# Skipping duplicate title: Modern Times
# Skipping duplicate title: The Lady Eve
# Skipping duplicate title: Yankee Doodle Dandy
# Skipping duplicate title: Red River
# Skipping duplicate title: Basic Instinct 2
# Skipping duplicate title: House of Frankenstein
# Skipping duplicate title: Destroy All Monsters
# Skipping duplicate title: The Quiet Man
# Skipping duplicate title: Shane
# Skipping duplicate title: The Night of the Hunter
# Skipping duplicate title: The Searchers
# Skipping duplicate title: Midnight Cowboy
# Skipping duplicate title: Nashville
# Skipping duplicate title: Gangs of New York
# Skipping duplicate title: Badlands
# Skipping duplicate title: Baise-moi
# Skipping duplicate title: Bambi Meets Godzilla
# Skipping duplicate title: Barry Lyndon
# Skipping duplicate title: Battle Royale
# Skipping duplicate title: Battle Royale II: Requiem
# Skipping duplicate title: Good Night, and Good Luck.
# Skipping duplicate title: Pirates of Silicon Valley
# Skipping duplicate title: Far from the Madding Crowd
# Skipping duplicate title: 88 Minutes
# Skipping duplicate title: Legionnaire
# Skipping duplicate title: I'll Sleep When I'm Dead
# Skipping duplicate title: Working Girl
# Skipping duplicate title: U-571
# Skipping duplicate title: Fame
# Skipping duplicate title: Reflections in a Golden Eye
# Skipping duplicate title: After the Wedding
# Skipping duplicate title: Girl, Interrupted
# Skipping duplicate title: I Now Pronounce You Chuck & Larry
# Skipping duplicate title: Changeling
# Skipping duplicate title: Prêt-à-Porter
# Skipping duplicate title: The Number 23
# Skipping duplicate title: I Know What You Did Last Summer
# Skipping duplicate title: I Still Know What You Did Last Summer
# Skipping duplicate title: Flash Gordon
# Skipping duplicate title: Girl with a Pearl Earring
# Skipping duplicate title: Mostly Martha
# Skipping duplicate title: What's New Pussycat?
# Skipping duplicate title: 54
# Skipping duplicate title: Flags of Our Fathers
# Skipping duplicate title: In July
# Skipping duplicate title: Onibaba
# Skipping duplicate title: The Lady from Shanghai
# Skipping duplicate title: Gilda
# Skipping duplicate title: Throne of Blood
# Skipping duplicate title: Red Beard
# Skipping duplicate title: Ikiru
# Skipping duplicate title: Dark Blue Almost Black
# Skipping duplicate title: I'm Not There.
# Skipping duplicate title: Corpse Bride
# Skipping duplicate title: Critters
# Skipping duplicate title: What Women Want
# Skipping duplicate title: Team America: World Police
# Skipping duplicate title: Beetlejuice
# Skipping duplicate title: The Believer
# Skipping duplicate title: Last Year at Marienbad
# Skipping duplicate title: Going Places
# Skipping duplicate title: My Girl
# Skipping duplicate title: Black Rain
# Skipping duplicate title: Bloody Sunday
# Skipping duplicate title: The Transporter
# Skipping duplicate title: Blow
# Skipping duplicate title: Shoot 'Em Up
# Skipping duplicate title: Road to Perdition
# Skipping duplicate title: Revolutionary Road
# Skipping duplicate title: Breach
# Skipping duplicate title: Stromboli
# Skipping duplicate title: Death on the Nile
# Skipping duplicate title: Women on the Verge of a Nervous Breakdown
# Skipping duplicate title: Scream 2
# Skipping duplicate title: Scream 3
# Skipping duplicate title: Visitor Q
# Skipping duplicate title: Scary Movie
# Skipping duplicate title: Scary Movie 2
# Skipping duplicate title: Scary Movie 3
# Skipping duplicate title: Scary Movie 4
# Skipping duplicate title: Get Out Your Handkerchiefs
# Skipping duplicate title: Appointment with Death
# Skipping duplicate title: Millennium
# Skipping duplicate title: The Sleeping Car Murder
# Skipping duplicate title: Charlie's Angels
# Skipping duplicate title: Atonement
# Skipping duplicate title: Munchies
# Skipping duplicate title: Monster-in-Law
# Skipping duplicate title: Asoka
# Skipping duplicate title: 2010
# Skipping duplicate title: The Snows of Kilimanjaro
# Skipping duplicate title: Seabiscuit
# Skipping duplicate title: My Super Ex-Girlfriend
# Skipping duplicate title: Jean de Florette
# Skipping duplicate title: Manon of the Spring
# Skipping duplicate title: The Return of Martin Guerre
# Skipping duplicate title: Diva
# Skipping duplicate title: Friday the 13th
# Skipping duplicate title: Viridiana
# Skipping duplicate title: The Assassination of Jesse James by the Coward Robert Ford
# Skipping duplicate title: 30 Days of Night
# Skipping duplicate title: Elizabeth: The Golden Age
# Skipping duplicate title: Elizabeth
# Skipping duplicate title: The Darjeeling Limited
# Skipping duplicate title: Hearts of Darkness: A Filmmaker's Apocalypse
# Skipping duplicate title: The Meaning of Life
# Skipping duplicate title: Panic Room
# Skipping duplicate title: Be Cool
# Skipping duplicate title: A Tale of Two Sisters
# Skipping duplicate title: The Machinist
# Skipping duplicate title: Nightwatching
# Skipping duplicate title: Sex and the City
# Skipping duplicate title: Michael Clayton
# Skipping duplicate title: Mermaids
# Skipping duplicate title: Lust, Caution
# Skipping duplicate title: The Discreet Charm of the Bourgeoisie
# Skipping duplicate title: Armored
# Skipping duplicate title: Raising Helen
# Skipping duplicate title: The Sum of All Fears
# Skipping duplicate title: December Boys
# Skipping duplicate title: Hot Fuzz
# Skipping duplicate title: Across the Universe
# Skipping duplicate title: Sympathy for Mr. Vengeance
# Skipping duplicate title: Southland Tales
# Skipping duplicate title: Gone Baby Gone
# Skipping duplicate title: Cul-de-sac
# Skipping duplicate title: The Garden of the Finzi-Continis
# Skipping duplicate title: Runaway Bride
# Skipping duplicate title: Ghost Dog: The Way of the Samurai
# Skipping duplicate title: Layer Cake
# Skipping duplicate title: The Invasion
# Skipping duplicate title: And Then There Were None
# Skipping duplicate title: The Day of the Jackal
# Skipping duplicate title: Dark Blue
# Skipping duplicate title: Guilty as Sin
# Skipping duplicate title: A Boy and His Dog
# Skipping duplicate title: The Curious Case of Benjamin Button
# Skipping duplicate title: Zardoz
# Skipping duplicate title: Edge of Seventeen
# Skipping duplicate title: Hang 'em High
# Skipping duplicate title: Leatherheads
# Skipping duplicate title: Burn After Reading
# Skipping duplicate title: 10 Things I Hate About You
# Skipping duplicate title: Be Kind Rewind
# Skipping duplicate title: The Legend of Bagger Vance
# Skipping duplicate title: The International
# Skipping duplicate title: Synecdoche, New York
# Skipping duplicate title: Mimic
# Skipping duplicate title: Knocked Up
# Skipping duplicate title: Impostor
# Skipping duplicate title: Gothika
# Skipping duplicate title: Under the Sand
# Skipping duplicate title: Five Times Two
# Skipping duplicate title: Love Is the Devil: Study for a Portrait of Francis Bacon
# Skipping duplicate title: White Lightning
# Skipping duplicate title: The Longest Yard
# Skipping duplicate title: Forbidden Games
# Skipping duplicate title: Before Night Falls
# Skipping duplicate title: Vicky Cristina Barcelona
# Skipping duplicate title: Prospero's Books
# Skipping duplicate title: Ashes and Diamonds
# Skipping duplicate title: Severance
# Skipping duplicate title: The Sugarland Express
# Skipping duplicate title: The Day of the Locust
# Skipping duplicate title: Martian Child
# Skipping duplicate title: Sky Captain and the World of Tomorrow
# Skipping duplicate title: Hannah and Her Sisters
# Skipping duplicate title: To Be and to Have
# Skipping duplicate title: The Astronaut Farmer
# Skipping duplicate title: Rush Hour 2
# Skipping duplicate title: The Prime of Miss Jean Brodie
# Skipping duplicate title: Wild Orchid
# Skipping duplicate title: The Boss of It All
# Skipping duplicate title: Hercules in New York
# Skipping duplicate title: The Dish
# Skipping duplicate title: Gosford Park
# Skipping duplicate title: Teorema
# Skipping duplicate title: Salò, or the 120 Days of Sodom
# Skipping duplicate title: The Hunting Party
# Skipping duplicate title: RoboCop
# Skipping duplicate title: RoboCop 2
# Skipping duplicate title: RoboCop 3
# Skipping duplicate title: Space Cowboys
# Skipping duplicate title: The Phantom of Liberty
# Skipping duplicate title: Bee Movie
# Skipping duplicate title: Fermat's Room
# Skipping duplicate title: Cousin, Cousine
# Skipping duplicate title: Alice's Restaurant
# Skipping duplicate title: The James Dean Story
# Skipping duplicate title: Luther
# Skipping duplicate title: Elvira, Mistress of the Dark
# Skipping duplicate title: Pee-wee's Big Adventure
# Skipping duplicate title: The Blue Lagoon
# Skipping duplicate title: The Canterbury Tales
# Skipping duplicate title: Hoosiers
# Skipping duplicate title: Amazon Women on the Moon
# Skipping duplicate title: Beyond the Valley of the Dolls
# Skipping duplicate title: Once
# Skipping duplicate title: Torn Curtain
# Skipping duplicate title: Waiter
# Skipping duplicate title: National Lampoon's Christmas Vacation
# Skipping duplicate title: Showtime
# Skipping duplicate title: Angel Eyes
# Skipping duplicate title: Family Plot
# Skipping duplicate title: The Mist
# Skipping duplicate title: In the Realm of the Senses
# Skipping duplicate title: The Northerners
# Skipping duplicate title: The Dress
# Skipping duplicate title: Into the Wild
# Skipping duplicate title: Tom Horn
# Skipping duplicate title: The Towering Inferno
# Skipping duplicate title: Nevada Smith
# Skipping duplicate title: The Hunter
# Skipping duplicate title: The Sand Pebbles
# Skipping duplicate title: Papillon
# Skipping duplicate title: The Jane Austen Book Club
# Skipping duplicate title: The Pledge
# Skipping duplicate title: Fanny & Alexander
# Skipping duplicate title: Along Came Polly
# Skipping duplicate title: The Woman in Red
# Skipping duplicate title: The Last Laugh
# Skipping duplicate title: The Family Man
# Skipping duplicate title: Dr. Mabuse, the Gambler
# Skipping duplicate title: Romeo and Juliet
# Skipping duplicate title: P.S. I Love You
# Skipping duplicate title: The Mirror Crack'd
# Skipping duplicate title: Murder by Death
# Skipping duplicate title: Shanghai Knights
# Skipping duplicate title: The Witches of Eastwick
# Skipping duplicate title: The Mexican
# Skipping duplicate title: 13 Tzameti
# Skipping duplicate title: Revenge of the Pink Panther
# Skipping duplicate title: Salvador
# Skipping duplicate title: Dracula
# Skipping duplicate title: Spice World
# Skipping duplicate title: Fracture
# Skipping duplicate title: Dreamcatcher
# Skipping duplicate title: Read My Lips
# Skipping duplicate title: Cat People
# Skipping duplicate title: Reign of Fire
# Skipping duplicate title: Sister Act 2: Back in the Habit
# Skipping duplicate title: Coyote Ugly
# Skipping duplicate title: Brotherhood of the Wolf
# Skipping duplicate title: Blue Thunder
# Skipping duplicate title: The Chamber
# Skipping duplicate title: Taking Care of Business
# Skipping duplicate title: SLC Punk
# Skipping duplicate title: Nosferatu the Vampyre
# Skipping duplicate title: Hotel Chevalier
# Skipping duplicate title: Practical Magic
# Skipping duplicate title: The Shipping News
# Skipping duplicate title: Guarding Tess
# Skipping duplicate title: Alvin and the Chipmunks
# Skipping duplicate title: Beyond the Sea
# Skipping duplicate title: I Am Legend
# Skipping duplicate title: Arachnophobia
# Skipping duplicate title: The Dukes of Hazzard
# Skipping duplicate title: The Contender
# Skipping duplicate title: Life Stinks
# Skipping duplicate title: Talk to Me
# Skipping duplicate title: Charlie Wilson's War
# Skipping duplicate title: Idle Hands
# Skipping duplicate title: Walk Hard: The Dewey Cox Story
# Skipping duplicate title: Lars and the Real Girl
# Skipping duplicate title: Death in Venice
# Skipping duplicate title: National Treasure: Book of Secrets
# Skipping duplicate title: El Dorado
# Skipping duplicate title: Treasure Island
# Skipping duplicate title: Priceless
# Skipping duplicate title: Zathura: A Space Adventure
# Skipping duplicate title: The Ten Commandments
# Skipping duplicate title: Homeward Bound: The Incredible Journey
# Skipping duplicate title: The Gate
# Skipping duplicate title: Ben X
# Skipping duplicate title: The Village
# Skipping duplicate title: What's Up, Doc?
# Skipping duplicate title: Turner & Hooch
# Skipping duplicate title: The 40 Year Old Virgin
# Skipping duplicate title: The Wedding Date
# Skipping duplicate title: The Weather Man
# Skipping duplicate title: Something's Gotta Give
# Skipping duplicate title: The Baader Meinhof Complex
# Skipping duplicate title: Australia
# Skipping duplicate title: In the Valley of Elah
# Skipping duplicate title: No Country for Old Men
# Skipping duplicate title: Big Trouble in Little China
# Skipping duplicate title: Rising Sun
# Skipping duplicate title: American Heart
# Skipping duplicate title: Ken Park
# Skipping duplicate title: Vampire's Kiss
# Skipping duplicate title: Perfect Stranger
# Skipping duplicate title: Cloverfield
# Skipping duplicate title: Dan in Real Life
# Skipping duplicate title: Airport '77
# Skipping duplicate title: Rebound
# Skipping duplicate title: Futurama: Bender's Big Score
# Skipping duplicate title: Matchstick Men
# Skipping duplicate title: Meet the Spartans
# Skipping duplicate title: Duplex
# Skipping duplicate title: The Man Without a Past
# Skipping duplicate title: Equilibrium
# Skipping duplicate title: Maid in Manhattan
# Skipping duplicate title: Alive
# Skipping duplicate title: Juno
# Skipping duplicate title: Carrie
# Skipping duplicate title: The Rage: Carrie 2
# Skipping duplicate title: City of Men
# Skipping duplicate title: There Will Be Blood
# Skipping duplicate title: The Bucket List
# Skipping duplicate title: Sleeping with the Enemy
# Skipping duplicate title: Chicken Run
# Skipping duplicate title: Tropic Thunder
# Skipping duplicate title: Titan A.E.
# Skipping duplicate title: xXx
# ...
# Skipping duplicate title: Night at the Museum: Secret of the Tomb
# Skipping duplicate title: Enemy
# Skipping duplicate title: Justice League: The Flashpoint Paradox
# Skipping duplicate title: Think Like a Man Too
# Skipping duplicate title: Somm
# Skipping duplicate title: Yeh Jawaani Hai Deewani
# Skipping duplicate title: Evocateur: The Morton Downey Jr. Movie
# Skipping duplicate title: Louis C.K.: Oh My God
# Skipping duplicate title: Boy Crazy
# Skipping duplicate title: Borgman
# Skipping duplicate title: 22 Jump Street
# Skipping duplicate title: A Million Ways to Die in the West
# Skipping duplicate title: Blue Ruin
# Skipping duplicate title: Entourage
# Skipping duplicate title: Last Summer in the Hamptons
# Skipping duplicate title: Star Trek Beyond
# Skipping duplicate title: The Pacific
# Skipping duplicate title: American Sniper
# Skipping duplicate title: We Are the Best!
# Skipping duplicate title: Jodorowsky's Dune
# Skipping duplicate title: Revenge for Jolly!
# Skipping duplicate title: Mandela: Long Walk to Freedom
# Skipping duplicate title: Kite
# Skipping duplicate title: Frank Herbert's Children of Dune
# Skipping duplicate title: Thou Gild'st the Even
# Skipping duplicate title: Lone Survivor
# Skipping duplicate title: Let's Be Cops
# Skipping duplicate title: The Selfish Giant
# Skipping duplicate title: Blackadder Back & Forth
# Skipping duplicate title: Punk's Dead: SLC Punk 2
# Skipping duplicate title: Birdman
# Skipping duplicate title: At Middleton
# Skipping duplicate title: Geography Club
# Skipping duplicate title: Coffee Town
# Skipping duplicate title: Chappie
# Skipping duplicate title: Million Dollar Arm
# Skipping duplicate title: Begin Again
# Skipping duplicate title: Ricky Gervais Live: Animals
# Skipping duplicate title: Ricky Gervais Live 3: Fame
# Skipping duplicate title: Family Band: The Cowsills Story
# Skipping duplicate title: Ricky Gervais Live 4: Science
# Skipping duplicate title: The Maze Runner
# Skipping duplicate title: The Frozen Ground
# Skipping duplicate title: The Blue Umbrella
# Skipping duplicate title: Draft Day
# Skipping duplicate title: Particle Fever
# Skipping duplicate title: The Same River Twice
# Skipping duplicate title: The Man from U.N.C.L.E.
# Skipping duplicate title: The Book Thief
# Skipping duplicate title: Philomena
# Skipping duplicate title: Sharknado
# Skipping duplicate title: The Judge
# Skipping duplicate title: The Imitation Game
# Skipping duplicate title: Welcome to the Jungle
# Skipping duplicate title: Predestination
# Skipping duplicate title: Spectre
# Skipping duplicate title: The Longest Week
# Skipping duplicate title: No Nukes
# Skipping duplicate title: Louis Theroux: America's Most Hated Family in Crisis
# Skipping duplicate title: Kingsman: The Secret Service
# Skipping duplicate title: The Borderlands
# Skipping duplicate title: Stonehearst Asylum
# Skipping duplicate title: Bad Grandpa
# Skipping duplicate title: Wetlands
# Skipping duplicate title: Plastic
# Skipping duplicate title: Batman v Superman: Dawn of Justice
# Skipping duplicate title: Enough Said
# Skipping duplicate title: Felony
# Skipping duplicate title: Ida
# Skipping duplicate title: Starred Up
# Skipping duplicate title: Bad Words
# Skipping duplicate title: Cold Comes the Night
# Skipping duplicate title: Locke
# Skipping duplicate title: Gone Girl
# Skipping duplicate title: Pursuit of Happiness
# Skipping duplicate title: Miss Violence
# Skipping duplicate title: The Sacrament
# Skipping duplicate title: Minions
# Skipping duplicate title: Gerontophilia
# Skipping duplicate title: Chef
# Skipping duplicate title: The Dog
# Skipping duplicate title: Toy Story of Terror!
# Skipping duplicate title: Words and Pictures
# Skipping duplicate title: Ted 2
# Skipping duplicate title: Violets Are Blue
# Skipping duplicate title: Fifty Shades of Grey
# Skipping duplicate title: Choices
# Skipping duplicate title: Coherence
# Skipping duplicate title: Ismael
# Skipping duplicate title: Aspen
# Skipping duplicate title: Two Days, One Night
# Skipping duplicate title: About Last Night
# Skipping duplicate title: The Fault in Our Stars
# Skipping duplicate title: Aloha
# Skipping duplicate title: The Making of a Legend: Gone with the Wind
# Skipping duplicate title: That Awkward Moment
# Skipping duplicate title: Non-Stop
# Skipping duplicate title: Sex Tape
# Skipping duplicate title: Tammy
# Skipping duplicate title: Marc Maron: Thinky Pain
# Skipping duplicate title: The Giver
# Skipping duplicate title: Horrible Bosses 2
# Skipping duplicate title: Stretch
# Skipping duplicate title: Unbroken
# Skipping duplicate title: Paranormal Activity: The Marked Ones
# Skipping duplicate title: Project Almanac
# Skipping duplicate title: The Peanuts Movie
# Skipping duplicate title: Back in the Day
# Skipping duplicate title: The Hundred-Foot Journey
# Skipping duplicate title: McFarland, USA
# Skipping duplicate title: Kidnapping Mr. Heineken
# Skipping duplicate title: Backcountry
# Skipping duplicate title: The Harvest
# Skipping duplicate title: Magic in the Moonlight
# Skipping duplicate title: Blended
# Skipping duplicate title: The Way He Looks
# Skipping duplicate title: The Cobbler
# Skipping duplicate title: Six by Sondheim
# Skipping duplicate title: Self/less
# Skipping duplicate title: The Purge: Anarchy
# Skipping duplicate title: St. Vincent
# Skipping duplicate title: Get on Up
# Skipping duplicate title: Search Party
# Skipping duplicate title: The Best of Me
# Skipping duplicate title: Unfinished Business
# Skipping duplicate title: This Is Where I Leave You
# Skipping duplicate title: Robot Overlords
# Skipping duplicate title: A Most Violent Year
# Skipping duplicate title: The Boy Next Door
# Skipping duplicate title: The Forsyte Saga
# Skipping duplicate title: Run All Night
# Skipping duplicate title: Beyond the Lights
# Skipping duplicate title: The Guest
# Skipping duplicate title: The Inbetweeners 2
# Skipping duplicate title: The Trip to Italy
# Skipping duplicate title: The One I Love
# Skipping duplicate title: The Babadook
# Skipping duplicate title: Ouija
# Skipping duplicate title: Nightcrawler
# Skipping duplicate title: Men, Women & Children
# Skipping duplicate title: Laggies
# Skipping duplicate title: I Origins
# Skipping duplicate title: Love Is Strange
# Skipping duplicate title: Into the Grizzly Maze
# Skipping duplicate title: The Voices
# Skipping duplicate title: Cold in July
# Skipping duplicate title: The Skeleton Twins
# Skipping duplicate title: Whiplash
# Skipping duplicate title: Suffragette
# Skipping duplicate title: Pawn Sacrifice
# Skipping duplicate title: Midnight Special
# Skipping duplicate title: True Story
# Skipping duplicate title: John Wick
# Skipping duplicate title: Kill the Messenger
# Skipping duplicate title: Every Thing Will Be Fine
# Skipping duplicate title: Tusk
# Skipping duplicate title: What We Do in the Shadows
# Skipping duplicate title: Obvious Child
# Skipping duplicate title: Hitman: Agent 47
# Skipping duplicate title: Nymphomaniac: Vol. II
# Skipping duplicate title: The End of the Tour
# Skipping duplicate title: Someone Marry Barry
# Skipping duplicate title: The Internet's Own Boy: The Story of Aaron Swartz
# Skipping duplicate title: No No: A Dockumentary
# Skipping duplicate title: The Battered Bastards of Baseball
# Skipping duplicate title: Wonderland
# Skipping duplicate title: Kung Fury
# Skipping duplicate title: A Girl Walks Home Alone at Night
# Skipping duplicate title: The Wedding Ringer
# Skipping duplicate title: And So It Goes
# Skipping duplicate title: Kelly & Cal
# Skipping duplicate title: Housebound
# Skipping duplicate title: Some Kind of Beautiful
# Skipping duplicate title: Land of Storms
# Skipping duplicate title: The Face of an Angel
# Skipping duplicate title: San Andreas
# Skipping duplicate title: Starry Eyes
# Skipping duplicate title: The Lobster
# Skipping duplicate title: Pitch Perfect 2
# Skipping duplicate title: Brick Mansions
# Skipping duplicate title: Zombeavers
# Skipping duplicate title: Muck
# Skipping duplicate title: Drive Hard
# Skipping duplicate title: As Above, So Below
# Skipping duplicate title: Swelter
# Skipping duplicate title: Wicked Blood
# Skipping duplicate title: Red Army
# Skipping duplicate title: The Water Diviner
# Skipping duplicate title: Danny Collins
# Skipping duplicate title: Paul Blart: Mall Cop 2
# Skipping duplicate title: Get Hard
# Skipping duplicate title: Pixels
# Skipping duplicate title: Goosebumps
# Skipping duplicate title: Just Before I Go
# Skipping duplicate title: A Fragile Trust: Plagiarism, Power, and Jayson Blair at the New York Times
# Skipping duplicate title: Carol
# Skipping duplicate title: The Legend of Tarzan
# Skipping duplicate title: Requiem For The Big East
# Skipping duplicate title: The Conjuring 2
# Skipping duplicate title: How to Be Single
# Skipping duplicate title: Life Partners
# Skipping duplicate title: Taken 3
# Skipping duplicate title: Black Mass
# Skipping duplicate title: Miss Meadows
# Skipping duplicate title: American Ultra
# Skipping duplicate title: Insurgent
# Skipping duplicate title: Ex Machina
# Skipping duplicate title: Magic Mike XXL
# Skipping duplicate title: The Canal
# Skipping duplicate title: Wild Tales
# Skipping duplicate title: İtirazım Var
# Skipping duplicate title: The Salvation
# Skipping duplicate title: Grimsby
# Skipping duplicate title: The Look of Silence
# Skipping duplicate title: London Has Fallen
# Skipping duplicate title: Elsa & Fred
# Skipping duplicate title: The Second Best Exotic Marigold Hotel
# Skipping duplicate title: Zootopia
# Skipping duplicate title: By the Gun
# Skipping duplicate title: It Follows
# Skipping duplicate title: Hail, Caesar!
# Skipping duplicate title: Penguins of Madagascar
# Skipping duplicate title: Captain America: Civil War
# Skipping duplicate title: Trainwreck
# Skipping duplicate title: The Possession of Michael King
# Skipping duplicate title: The DUFF
# Skipping duplicate title: The Hateful Eight
# Skipping duplicate title: Time Lapse
# Skipping duplicate title: Sicario
# Skipping duplicate title: Daddy's Home
# Skipping duplicate title: Joy
# Skipping duplicate title: The Last Witch Hunter
# Skipping duplicate title: The Disappearance of Eleanor Rigby: Her
# Skipping duplicate title: Ricki and the Flash
# Skipping duplicate title: The Adventures of Mary-Kate & Ashley: The Case of the United States Navy Adventure
# Skipping duplicate title: Experience Preferred...But Not Essential
# Skipping duplicate title: Comet
# Skipping duplicate title: Straight Outta Compton
# Skipping duplicate title: Playing It Cool
# Skipping duplicate title: The Maid's Room
# Skipping duplicate title: Seve
# Skipping duplicate title: Once My Mother
# Skipping duplicate title: Doctor Who: The Time of the Doctor
# Skipping duplicate title: Irrational Man
# Skipping duplicate title: 99 Homes
# Skipping duplicate title: Beasts of No Nation
# Skipping duplicate title: Top Five
# Skipping duplicate title: El vals de los inútiles
# Skipping duplicate title: Nixon by Nixon: In His Own Words
# Skipping duplicate title: Glen Campbell: I'll Be Me
# Skipping duplicate title: The Walk
# Skipping duplicate title: The Martian
# Skipping duplicate title: Two Night Stand
# Skipping duplicate title: Paper Towns
# Skipping duplicate title: Revenge of the Green Dragons
# Skipping duplicate title: Maggie
# Skipping duplicate title: 7 Days in Hell
# Skipping duplicate title: Catfish in Black Bean Sauce
# Skipping duplicate title: Olive Kitteridge
# Skipping duplicate title: The Rewrite
# Skipping duplicate title: The Huntsman: Winter's War
# Skipping duplicate title: Tracers
# Skipping duplicate title: Anomalisa
# Skipping duplicate title: Now You See Me 2
# Skipping duplicate title: Citizenfour
# Skipping duplicate title: Deadpool
# Skipping duplicate title: The Age of Adaline
# Skipping duplicate title: Tiger Orange
# Skipping duplicate title: Maze Runner: The Scorch Trials
# Skipping duplicate title: Son of a Gun
# Skipping duplicate title: Bone Tomahawk
# Skipping duplicate title: Sex Ed
# Skipping duplicate title: Pek Yakında
# Skipping duplicate title: Burnt
# Skipping duplicate title: Me Before You
# Skipping duplicate title: Bridge of Spies
# Skipping duplicate title: Vacation
# Skipping duplicate title: The Night Before
# Skipping duplicate title: Dying of the Light
# Skipping duplicate title: The Dressmaker
# Skipping duplicate title: The Atticus Institute
# Skipping duplicate title: Comedy Central Roast of James Franco
# Skipping duplicate title: Narcopolis
# Skipping duplicate title: Infini
# Skipping duplicate title: Central Intelligence
# Skipping duplicate title: Hello Ladies: The Movie
# Skipping duplicate title: Trailer Park Boys: Live at the North Pole
# Skipping duplicate title: Money Monster
# Skipping duplicate title: World of Tomorrow
# Skipping duplicate title: The Perfect Guy
# Skipping duplicate title: Partisan
# Skipping duplicate title: The Danish Girl
# Skipping duplicate title: Naomi and Ely's No Kiss List
# Skipping duplicate title: Southpaw
# Skipping duplicate title: The Wolfpack
# Skipping duplicate title: The Overnight
# Skipping duplicate title: People, Places, Things
# Skipping duplicate title: Nasty Baby
# Skipping duplicate title: Tangerine
# Skipping duplicate title: Me and Earl and the Dying Girl
# Skipping duplicate title: Last Knights
# Skipping duplicate title: Teenage Mutant Ninja Turtles: Out of the Shadows
# Skipping duplicate title: The D Train
# Skipping duplicate title: Dope
# Skipping duplicate title: Bad Asses on the Bayou
# Skipping duplicate title: I'll See You in My Dreams
# Skipping duplicate title: The Witch
# Skipping duplicate title: Cop Car
# Skipping duplicate title: As We Were Dreaming
# Skipping duplicate title: Creed
# Skipping duplicate title: Sword of Vengeance
# Skipping duplicate title: Green Room
# Skipping duplicate title: Spotlight
# Skipping duplicate title: Cocaine Cowboys: Reloaded
# Skipping duplicate title: The Boy and the Beast
# Skipping duplicate title: Miles Ahead
# Skipping duplicate title: Mike and Dave Need Wedding Dates
# Skipping duplicate title: Hyena Road
# Skipping duplicate title: The Purge: Election Year
# Skipping duplicate title: What Happened, Miss Simone?
# Skipping duplicate title: Going Clear: Scientology and the Prison of Belief
# Skipping duplicate title: Tig
# Skipping duplicate title: The Big Short
# Skipping duplicate title: Best of Enemies
# Skipping duplicate title: Listen to Me Marlon
# Skipping duplicate title: Victoria
# Skipping duplicate title: Hello, My Name Is Doris
# Skipping duplicate title: The Jinx: The Life and Deaths of Robert Durst
# Skipping duplicate title: Steve Jobs
# Skipping duplicate title: War Room
# Skipping duplicate title: Deathgasm
# Skipping duplicate title: Manson Family Vacation
# Skipping duplicate title: Twinsters
# Skipping duplicate title: Jason Bourne
# Skipping duplicate title: Neighbors 2: Sorority Rising
# Skipping duplicate title: Close Range
# Skipping duplicate title: Superfast!
# Skipping duplicate title: Life Is Sacred
# Skipping duplicate title: The Secret Life of Pets
# Skipping duplicate title: Approaching the Unknown
# Skipping duplicate title: Zoolander 2
# Skipping duplicate title: Ashby
# Skipping duplicate title: Sharknado 3: Oh Hell No!
# Skipping duplicate title: I Am Wrath
# Skipping duplicate title: Bana Masal Anlatma
# Skipping duplicate title: The Shallows
# Skipping duplicate title: 10 Cloverfield Lane
# Skipping duplicate title: Schneider vs. Bax
# Skipping duplicate title: Open Secret
# Skipping duplicate title: Solace
# Skipping duplicate title: Popstar: Never Stop Never Stopping
# Skipping duplicate title: Keanu
# Skipping duplicate title: Rubble Kings
# Skipping duplicate title: A Deadly Adoption
# Skipping duplicate title: Contracted: Phase II
# Skipping duplicate title: Tallulah
# Skipping duplicate title: Bajirao Mastani
# Skipping duplicate title: A Very Murray Christmas
# Skipping duplicate title: My Friend Rockefeller
# Skipping duplicate title: Sing Street
# Skipping duplicate title: SOMM: Into the Bottle
# Skipping duplicate title: The Lovers and the Despot
# Skipping duplicate title: Kill Command
# Skipping duplicate title: Ice Age: The Great Egg-Scapade
# Skipping duplicate title: Kingsglaive: Final Fantasy XV
# Skipping duplicate title: Sharknado 4: The 4th Awakens
# Skipping duplicate title: The Beatles: Eight Days a Week - The Touring Years
# Skipping duplicate title: Rustom
# Skipping duplicate title: Sunspring
# Skipping duplicate title: Mohenjo Daro

# %%
from celery import shared_task
from django.db import transaction
from django.utils import timezone
from movies.models import Movie

@shared_task
def task_update_movie_ratings_batch(movie_ids):
    for movie_id in movie_ids:
        qs = Movie.objects.filter(id=movie_id)
        if qs.exists():
            movie = qs.first()
            rating_avg = movie.rating_set.aggregate(Avg('rating'))['rating__avg']
            rating_count = movie.rating_set.count()
            score = decimal.Decimal(rating_avg * rating_count * 1.0)
            qs.update(
                rating_avg=rating_avg,
                rating_count=rating_count,
                score=score,
                rating_last_updated=timezone.now()
            )

# %%
import os

# Change the directory to the parent directory
os.chdir(r'C:\Users\USER\Documents\recommender\src\ratings\management\commands\commands')

# Define the command to be executed
command = "python manage.py update_movie_ratings"

# %%
import os
import time

# Record the start time
start_time = time.time()

# Change the directory to the parent directory
os.chdir(r'C:\Users\USER\Documents\recommender\src\ratings\management\commands\commands')

# Define the command to be executed
command = "python manage.py update_movie_ratings"

# Execute the command
os.system(command)

# Calculate the time taken
total_time = time.time() - start_time

# Print the time taken
print(f"Total time taken for ratings update: {total_time} seconds")
# Out:
# Total time taken for ratings update: 2.713663101196289 seconds
