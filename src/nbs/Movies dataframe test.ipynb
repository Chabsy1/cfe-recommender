# %%
import sys
import os
import django

# Manually set the root directory and the settings module
root_dir = os.path.abspath("C:/Users/USER/Documents/recommender/src")
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "cfehome.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Add the root directory to sys.path
if root_dir not in sys.path:
    sys.path.insert(0, root_dir)
    print(f"'{root_dir}' successfully added to sys.path")

# Setup Django
try:
    django.setup()
    print("Django setup successfully")
except Exception as e:
    print(f"Error setting up Django: {e}")

# Now you should be able to import your Django models
try:
    from movies.models import Movie
    print("Imported movies.models successfully")
except ModuleNotFoundError as e:
    print(f"Failed to import movies.models: {e}")
except Exception as e:
    print(f"An error occurred: {e}")

# If Django is set up correctly, you can query your models
try:
    qs = Movie.objects.all().values('title', 'release_date', 'rating_avg', 'rating_count')
    for movie in qs:
        print(movie)
    print("Movies queried successfully")
except Exception as e:
    print(f"Failed to query movies: {e}")
# Out:
# Django setup successfully
# Imported movies.models successfully
# {'title': 'Ariel', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Shadows in Paradise', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Four Rooms', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Judgment Night', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Star Wars', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Finding Nemo', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Forrest Gump', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'American Beauty', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Citizen Kane', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# {'title': 'Dancer in the Dark', 'release_date': None, 'rating_avg': None, 'rating_count': None}
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(qs)
df.head(n=10)
# Out:
#                  title release_date rating_avg  rating_count
# 0                Ariel         None       None           NaN
# 1  Shadows in Paradise         None       None           NaN
# 2           Four Rooms         None       None           NaN
# 3       Judgment Night         None       None           NaN
# 4            Star Wars         None       None           NaN
# 5         Finding Nemo         None       None           NaN
# 6         Forrest Gump         None       None           NaN
# 7      American Beauty         None       None           NaN
# 8         Citizen Kane         None       None           NaN
# 9   Dancer in the Dark         None       None           NaN

# %%
qs.first()
# Out:
# {'title': 'Ariel',
#  'release_date': None,
#  'rating_avg': None,
#  'rating_count': None}

# %%
# df.to_csv
